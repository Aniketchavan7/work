# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("dataset1/academic.csv")

# %%
df.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
df.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
df['Topic']=df['Topic'].fillna('0')

# %%
df.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
df['Relation'].dropna(axis=0, inplace=False)
# Out:
# 0      Father
# 1      Father
# 2      Father
# 3      Father
# 4      Father
#         ...
# 475    Father
# 476    Father
# 477    Father
# 478    Father
# 479    Father
# Name: Relation, Length: 480, dtype: object

# %%
df.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
df = df.dropna(subset=['Relation', 'GradeID'])

# %%
df['raisedhands'].replace(np.NaN,df['raisedhands'].mean())
# Out:
# 0      15
# 1      20
# 2      10
# 3      30
# 4      40
#        ..
# 475     5
# 476    50
# 477    55
# 478    30
# 479    35
# Name: raisedhands, Length: 480, dtype: int64

# %%
df.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   480.000000        480.000000         480.000000  480.000000
# mean     46.775000         54.797917          37.918750   43.283333
# std      30.779223         33.080007          26.611244   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      15.750000         20.000000          14.000000   20.000000
# 50%      50.000000         65.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %%
import matplotlib.pyplot as plt

# %%
df['Semester'].value_counts()
# Out:
# Semester
# F    245
# S    235
# Name: count, dtype: int64

# %%
fig,x=plt.subplots(figsize=(5,5))
ax=plt.hist(df['Semester'],color='b',edgecolor='b')
plt.show()

# %%
df.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
df['ParentAnsweringSurvey'].value_counts()
# Out:
# ParentAnsweringSurvey
# Yes    270
# No     210
# Name: count, dtype: int64

# %%
df.drop(['ParentAnsweringSurvey'],axis=1)
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# ...

# %%
df['raisedhands']=df['raisedhands']/df['raisedhands'].max()
df['VisITedResources']=df['VisITedResources']/df['VisITedResources'].max()

# %%
df[['VisITedResources','raisedhands']].head()
# Out:
#    VisITedResources  raisedhands
# 0          0.161616         0.15
# 1          0.202020         0.20
# 2          0.070707         0.10
# 3          0.252525         0.30
# 4          0.505051         0.40

# %%
df['GradeID'].value_counts()
# Out:
# GradeID
# G-02    147
# G-08    116
# G-07    101
# G-04     48
# G-06     32
# G-11     13
# G-12     11
# G-09      5
# G-10      4
# G-05      3
# Name: count, dtype: int64

# %%
df['GradeID'].replace({"G-02":1,"G-04":2,"G-05":3,"G-06":4,"G-07":5,"G-08":6,"G-09":7,"G-10":8,"G-11":9,"G-12":10})
# Out:
# C:\Users\Aniket\AppData\Local\Temp\ipykernel_4224\1481555875.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['GradeID'].replace({"G-02":1,"G-04":2,"G-05":3,"G-06":4,"G-07":5,"G-08":6,"G-09":7,"G-10":8,"G-11":9,"G-12":10})
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 475    6
# 476    6
# 477    6
# 478    6
# 479    6
# Name: GradeID, Length: 480, dtype: int64

# %%
df['GradeID'].value_counts()
# Out:
# GradeID
# G-02    147
# G-08    116
# G-07    101
# G-04     48
# G-06     32
# G-11     13
# G-12     11
# G-09      5
# G-10      4
# G-05      3
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father         0.15          0.161616                  2
# 1        F   Father         0.20          0.202020                  3
# 2        F   Father         0.10          0.070707                  0
# 3        F   Father         0.30          0.252525                  5
# 4        F   Father         0.40          0.505051                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
df['StudentAbsenceDays'].value_counts()
# Out:
# StudentAbsenceDays
# Under-7    289
# Above-7    191
# Name: count, dtype: int64

# %%
df['StudentAbsenceDays'].replace({"Under-7":"0","Above-7":"1"})
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 475    1
# 476    0
# 477    0
# 478    1
# 479    1
# Name: StudentAbsenceDays, Length: 480, dtype: object

# %%
df.StudentAbsenceDays.replace({"Under-7":0,"Above-7":1})
df['StudentAbsenceDays'].value_counts()
# Out:
# C:\Users\Aniket\AppData\Local\Temp\ipykernel_4224\3283693196.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.StudentAbsenceDays.replace({"Under-7":0,"Above-7":1})
# StudentAbsenceDays
# Under-7    289
# Above-7    191
# Name: count, dtype: int64

# %%
df['Discussion'].value_counts()
# Out:
# Discussion
# 70    24
# 40    23
# 33    21
# 50    18
# 30    17
#       ..
# 95     1
# 65     1
# 76     1
# 73     1
# 62     1
# Name: count, Length: 90, dtype: int64

# %%
minval=df['Discussion'].min()
maxval=df['Discussion'].max()

# %%
bins=np.linspace(minval,maxval,4)
bins
# Out:
# array([ 1.        , 33.66666667, 66.33333333, 99.        ])

# %%
labels=['small','medium','big']

# %%
 df['bins']=pd.cut(df['Discussion'],bins=bins,labels=labels)

# %%
df['bins'].value_counts()
# Out:
# bins
# small     218
# medium    130
# big       129
# Name: count, dtype: int64

# %%
df
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         0.15          0.161616
# ...
